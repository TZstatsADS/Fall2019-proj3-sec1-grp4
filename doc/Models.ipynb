# %%
from scipy.io import loadmat
import os

# %%
data_path = "../data/train_set/train_set/points"
points1 = loadmat(os.path.join(data_path, '0001.mat'))

# %%
points1
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Thu Jan 03 10:39:19 2013',
#  '__version__': '1.0',
#  '__globals__': [],
#  'faceCoordinatesUnwarped': array([[457.3140625 , 365.6140625 ],
#         [411.5265625 , 369.7765625 ],
#         [428.73259545, 356.48153354],
#         [450.54869337, 353.1037147 ],
#         [472.66609476, 353.90941251],
#         [493.7359375 , 360.4109375 ],
#         [479.3130121 , 378.03184984],
#         [455.97982045, 381.41555068],
#         [432.33191494, 380.32132109],
#         [633.22395833, 365.97395833],
#         [592.90104167, 371.734375  ],
#         [612.77869235, 359.15711954],
#         [636.34696519, 356.11107574],
#         [659.85369978, 359.57333609],
#         [680.13020833, 371.734375  ],
#         [658.66435152, 377.97934374],
#         [636.40847221, 380.22113148],
#         [614.10443409, 378.67420412],
#         [392.26281113, 329.42606149],
#         [415.02346805, 304.81178521],
# ...
